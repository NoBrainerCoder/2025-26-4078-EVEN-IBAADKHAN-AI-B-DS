# %% [markdown]
# <a href="https://colab.research.google.com/github/sripathiamulya15/2025-26-4103-S.Amulya-AI-B-DS/blob/main/Week-2/sortingtechniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### ***DATE : 10/2/2026***

# %% [markdown]
# # *SORTING ALGORITHMS*

# %%
#SELECTION SORT
n=int(input("Enter number of elements: "))
arr=[]
for i in range(n):
    arr.append(int(input(f"Enter element{i+1}:")))
print("\nOriginal array:",arr)
for i in range(n-1):
    min_index=i
    for j in range(i+1,n):
        if arr[j]<arr[min_index]:
            min_index=j
    #swap AFTER finding the minimum
    arr[i],arr[min_index]=arr[min_index],arr[i]
print("Sorted array:",arr)
# Out:
# Enter number of elements: 5
# Enter element1:1
# Enter element2:7
# Enter element3:4
# Enter element4:9
# Enter element5:3
#
# Original array: [1, 7, 4, 9, 3]
# Sorted array: [1, 3, 4, 7, 9]

# %%
#BUBBLE SORT
n=int(input("Enter number of elements: "))
arr=[]
for i in range(n):
    arr.append(int(input(f"Enter element {i+1}:")))
print("\nOriginal array:",arr)
for i in range(n-1):
  for j in range(n-1-i):
    if arr[j]>arr[j+1]:
      arr[j],arr[j+1]=arr[j+1],arr[j]
print("Sorted array:",arr)
# Out:
# Enter number of elements: 5
# Enter element 1:8
# Enter element 2:3
# Enter element 3:5
# Enter element 4:6
# Enter element 5:2
#
# Original array: [8, 3, 5, 6, 2]
# Sorted array: [2, 3, 5, 6, 8]
